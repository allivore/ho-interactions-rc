# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
with open("Results/Entropy/fig8d.pkl", "rb") as f:
    data = pickle.load(f)
red_vals = data["red_vals"]
syn_vals = data["syn_vals"]
good_count = data["good_count"]

# %%
plt.pcolormesh(red_vals, syn_vals, good_count.T, cmap="inferno")
plt.colorbar()
